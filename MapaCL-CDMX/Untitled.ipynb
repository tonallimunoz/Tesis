# %%
plotshape(cdmx)
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64,Float64,Float64,Float64}(-1.1063616196474127e7, 2.228061002074503e6, 51995.49999395404, -70656.85308370586, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.SimplePolygonPrimitive{Tuple{Length{:cx,Float64},Length{:cy,Float64}}}}(Compose.SimplePolygonPrimitive{Tuple{Length{:cx,Float64},Length{:cy,Float64}}}[Compose.SimplePolygonPrimitive{Tuple{Length{:cx,Float64},Length{:cy,Float64}}}(Tuple{Length{:cx,Float64},Length{:cy,Float64}}[(-1.1018283840290388e7cx, 2.1931108601596984e6cy), (-1.1018242932937872e7cx, 2.193107551704508e6cy), (-1.1018234777449334e7cx, 2.193191027791105e6cy), (-1.101821732600408e7cx, 2.1931947355749775e6cy), (-1.1018203167834645e7cx, 2.193276075904656e6cy), (-1.1018172388886003e7cx, 2.1932706621943605e6cy), (-1.1018185637575198e7cx, 2.1932361180
# ...
